# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Occurrence

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
occurrence = {
    'male' : [0.54491018, 0.556420233, 0.637037037, 0.55353902, 0.53414264, 0.592438563, 0.510444563],
    'female' : [0.45508982, 0.443579767, 0.362962963, 0.44646098, 0.46585736, 0.407561437, 0.489555437]
}
df = pd.DataFrame(occurrence)
df.index = ['African', 'EastEU', 'Indo', 'Islam', 'Sino', 'Western', 'Latin']

# %%
df.plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# # Firstness

# %%
firstness = {
    'male': [0.547619048, 0.857142857,0.733333333, 0.696969697, 0.75, 0.547619048,0.519337017],
    'female' : [0.452380952, 0.142857143, 0.266666667, 0.303030303, 0.25, 0.452380952, 0.480662983]
}
df = pd.DataFrame(firstness)
df.index = ['African', 'EastEU', 'Indo', 'Islam', 'Sino', 'Western', 'Latin']
df.plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: >

# %% [markdown]
# # Names

# %%
FF = [1,1,3,2,2,0,3,3]
FM = [5,5,3,0,0,0,1,2]
MF = [1,6,0,0,0,0,0,1]
MM = [8,4,3,7,0,11,7,6]
names = {
    'FF' : [1,1,3,2,2,0,3,3],
    'FM' : [5,5,3,0,0,0,1,2],
    'MF' : [1,6,0,0,0,0,0,1],
    'MM' : [8,4,3,7,0,11,7,6]
}
df = pd.DataFrame(names)

# %%
fContext = {
    'FM' : [5,5,3,0,0,0,1,2],
    'FF' : [1,1,3,2,2,0,3,3]
}
df = pd.DataFrame(fContext)
df.index = ['African', 'EastEU', 'Indo', 'Islam', 'Sino', 'Western', 'Latin','Total']
df.plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: >

# %%
mContext = {
    'MM' : [8,4,3,7,0,11,7,6],
    'MF' : [1,6,0,0,0,0,0,1]
}
df = pd.DataFrame(mContext)
df.index = ['African', 'EastEU', 'Indo', 'Islam', 'Sino', 'Western', 'Latin','Total']
df.plot(kind='bar', stacked=True, figsize=(10, 6))
# Out:
# <Axes: >
