# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# # Occurrence

# %%
occurrence = [0.835,0.797,0.570,0.807,0.872,0.691,0.959,0.785]

# %%
plt.hist(occurrence, bins=8)
# Out:
# (array([1., 0., 1., 0., 3., 1., 1., 1.]),
#  array([0.57    , 0.618625, 0.66725 , 0.715875, 0.7645  , 0.813125,
#         0.86175 , 0.910375, 0.959   ]),
#  <BarContainer object of 8 artists>)

# %%
sns.stripplot(y=occurrence)
# Out:
# <Axes: >

# %% [markdown]
# # Firstness

# %%
firstness = [0.82,0.17,0.36,0.43,0.33,0.83,0.93,0.74]

# %%
sns.stripplot(y=firstness)
# Out:
# <Axes: >

# %% [markdown]
# # Sentiment analysis score

# %%
#(fem pos - fem neg)-(mal pos - mal neg)
senti = [0.031, -0.039,-0.03,-0.007,-0.028,0.001,-0.002,-0.009 ]

# %%
sns.stripplot(y=senti)
# Out:
# <Axes: >

# %%
plt.hist(senti, bins = 8)
# Out:
# (array([1., 2., 0., 2., 2., 0., 0., 1.]),
#  array([-0.039  , -0.03025, -0.0215 , -0.01275, -0.004  ,  0.00475,
#          0.0135 ,  0.02225,  0.031  ]),
#  <BarContainer object of 8 artists>)

# %% [markdown]
# # Names

# %%
FF = [1,1,3,2,2,0,3,3]
FM = [5,5,3,0,0,0,1,2]
MF = [1,6,0,0,0,0,0,1]
MM = [8,4,3,7,0,11,7,6]

# %%
x = np.arange(len(FF))
width = 0.2
fig, ax = plt.subplots()

ax.bar(x - 1.5*width, FF, width, label='FF',color='purple')
ax.bar(x - 0.5*width, FM, width, label='FM',color='gold')
ax.bar(x + 0.5*width, MF, width, label='MF',color='indigo')
ax.bar(x + 1.5*width, MM, width, label='MM',color='yellow')
ax.legend()

# %%
x = np.arange(len(FF))
width = 0.4
fig, ax = plt.subplots()
ax.bar(x - width/2, FF, width, label='FF', color='purple')
ax.bar(x + width/2, FM, width, label='FM', color='gold')
ax.legend()

# %%
x = np.arange(len(MF))
width = 0.4
fig, ax = plt.subplots()
ax.bar(x - width/2, MF, width, label='FF', color='indigo')
ax.bar(x + width/2, MM, width, label='FM', color='yellow')
ax.legend()
